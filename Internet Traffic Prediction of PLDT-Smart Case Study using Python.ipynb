# %% [markdown]
# # **Broadband Traffic Prediction of PLDT-Smart Case Study**
#
# **Author:** Nicole John Mortel

# %% [markdown]
# # **Abstract**

# %% [markdown]
# This study aims to develop a model to predict broadband traffic of PLDT, one of the top Internet Service Provider (ISP) in the Philippines. By leveraging data science approaches, the model seeks to predict broadband traffic using the Auto ARIMA model. This use case will help the operation as their reference for the analysis of network congestion and provide warnings to optimize network infrastructure, bandwidth allocation, and service quality.

# %% [markdown]
# # **Introduction**

# %% [markdown]
# In the Philippines, ISPs like PLDT face challenges in managing network infrastructure due to unpredictable broadband traffic and processing big data is also a challenge. This study proposes a solution to this problem by developing a model that can predict broadband traffic using the ARIMA model, thereby enabling PLDT to optimize its network infrastructure and improve service quality.

# %% [markdown]
# # **Methodology**

# %% [markdown]
# The study will utilize a data science approach, exploring the implementation of forecasting models and employing the power of using large dataset. Historical data on broadband traffic monthly from 2020 up to 2024 will be collected and used to train the model. After doing some research, ARIMA model and Prophet are the two trendy models applicable to this case study. The model’s performance will be evaluated based on its accuracy in predicting internet traffic.

# %% [markdown]
# ## **1. Data Collection and Pre-processing:** Collect datasets from data sources with internal and external stakeholders. Preprocess and consolidate data for analysis
#
# **Note**: this process was done outside this notebook using Tableau Pre-builder

# %% [markdown]
# ## **2. Data Transformation and EDA:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
# Load the dataset
data = pd.read_csv('/content/drive/MyDrive/Classroom/MSDS 511 - Time Series Data Analysis and Forecasting 2023-2024/Internet Traffic Prediction Use Case Project/Dataset/Monthly Traffic and Usage.csv')
data['Date'] = pd.to_datetime(data['Date'])

# %%
# Set 'Date' as the index
data.set_index('Date', inplace=True)

# %%
# Explore the first few rows and summary statistics
print(data.head())
print(data.describe())
# Out:
#             Total Internet Traffic (Tbps)  Fixed Traffic (Tbps)  Usage (PB)  \
# Date
# 2020-01-31                            4.8                   3.3        20.7
# 2020-02-29                            5.2                   3.5        21.0
# 2020-03-31                            5.9                   4.1        28.2
# 2020-04-30                            6.0                   4.2        28.5
# 2020-05-31                            6.1                   4.3        27.8
#
#             Ave Usage Per Subs (GB)
# Date
# 2020-01-31                    13.26
# 2020-02-29                    13.83
# 2020-03-31                    15.20
# 2020-04-30                    16.25
# 2020-05-31                    16.25
#        Total Internet Traffic (Tbps)  Fixed Traffic (Tbps)  Usage (PB)  \
# count                      52.000000             52.000000   51.000000
# mean                       11.567885              8.657692   55.688824
# ...

# %%
# Time series plot of total internet traffic
data['Total Internet Traffic (Tbps)'].plot(title='Total Internet Traffic Over Time')
plt.show()

# %%
# Decomposition of time series to observe trends and seasonality
result = seasonal_decompose(data['Total Internet Traffic (Tbps)'], model='additive')
result.plot()
plt.show()

# %% [markdown]
# # **Results**

# %% [markdown]
# While the results section will be filled in after the study is conducted, it is expected that the model will accurately predict internet traffic patterns and potential network congestion areas. This will enable PLDT to take proactive measures in managing its network infrastructure, potentially leading to improved service quality and customer satisfaction.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# The study aims to address the critical issue of network congestion in ISPs by developing a predictive model for internet traffic patterns. If successful, this model could significantly enhance PLDT’s ability to manage its network infrastructure and improve service quality.

# %% [markdown]
# # **Recommendation**

# %% [markdown]
# Based on the study’s findings, it is recommended that PLDT adopt the predictive model in its network management practices. Further research could also be conducted to refine the model and explore its applicability to other ISPs in the Philippines and globally.
